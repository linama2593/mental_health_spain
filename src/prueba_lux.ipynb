# %%
import lux

# %%
#Importamos y guardamos el dataframe

import pandas as pd

RUTA_DATAFRAME = '../data/processed/df_final.csv'

df = pd.read_csv(RUTA_DATAFRAME, sep=',')

# %%
df
# Out:
# /home/tr4shhh/venv/lib/python3.11/site-packages/IPython/core/formatters.py:922: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# /home/tr4shhh/venv/lib/python3.11/site-packages/lux/core/frame.py:632: UserWarning:Traceback (most recent call last):
#   File "/home/tr4shhh/venv/lib/python3.11/site-packages/lux/core/frame.py", line 594, in _ipython_display_
#     self.maintain_recs()
#   File "/home/tr4shhh/venv/lib/python3.11/site-packages/lux/core/frame.py", line 436, in maintain_recs
#     custom_action_collection = custom_actions(rec_df)
#                                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/tr4shhh/venv/lib/python3.11/site-packages/lux/action/custom.py", line 76, in custom_actions
#     recommendation = lux.config.actions[action_name].action(ldf)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
