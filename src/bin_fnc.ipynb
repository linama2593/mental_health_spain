# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/mental_health.csv')

# %%
to_binary = [
    "G25a_1",
    "G25b_1",
    "G25c_1",
    "G25a_2",
    "G25b_2",
    "G25c_2",
    "G25d_2",
    "G25a_3",
    "G25b_3",
    "G25c_3",
    "G25a_4",
    "G25b_4",
    "G25c_4",
    "G25a_5",
    "G25b_5",
    "G25c_5",
    "G25a_6",
    "G25b_6",
    "G25c_6",
    "G25a_7",
    "G25b_7",
    "G25c_7",
    "G25a_8",
    "G25b_8",
    "G25c_8",
    "G25a_9",
    "G25b_9",
    "G25c_9",
    "G25a_10",
    "G25b_10",
    "G25c_10",
    "G25a_11",
    "G25b_11",
    "G25c_11",
    "G25a_12",
    "G25b_12",
    "G25c_12",
    "G25a_13",
    "G25b_13",
    "G25c_13",
    "G25a_14",
    "G25b_14",
    "G25c_14",
    "G25a_15",
    "G25b_15",
    "G25c_15",
    "G25a_16",
    "G25b_16",
    "G25c_16",
    "G25a_17",
    "G25b_17",
    "G25c_17",
    "G25a_18",
    "G25b_18",
    "G25c_18",
    "G25a_19",
    "G25b_19",
    "G25c_19",
    "G25a_22",
    "G25b_22",
    "G25c_22",
    "G25a_23",
    "G25b_23",
    "G25c_23",
    "G25d_23",
    "G25a_24",
    "G25b_24",
    "G25c_24",
    "G25a_25",
    "G25b_25",
    "G25c_25",
    "G25a_26",
    "G25b_26",
    "G25c_26",
    "G25a_27",
    "G25b_27",
    "G25c_27",
    "G25a_28",
    "G25b_28",
    "G25c_28",
    "G25a_29",
    "G25b_29",
    "G25c_29",
    "G25a_30",
    "G25b_30",
    "G25c_30",
    "G25a_31",
    "G25b_31",
    "G25c_31",
    "G25a_32",
    "G25b_32",
    "G25c_32"
]

# %%
def binarize(df, target):
    df_filt = df[target]
    df_bi = df_filt.map(lambda x :  1 if x == 1 else 0)
    df_final = pd.concat([df, df_bi], axis=1)
    return df_final

# %%
binarized_df = binarize(df, to_binary)
print(binarized_df)
#insert
