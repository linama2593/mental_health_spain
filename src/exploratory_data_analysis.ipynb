# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ##### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import dataframe

# %%
#Importamos y guardamos el dataframe

import pandas as pd

RUTA_DATAFRAME = '../data/processed/df_final.csv'

df = pd.read_csv(RUTA_DATAFRAME, sep=',')

# %%
df
# Out:
#        CCAA  SEXOa  EDADa  E1_1  E1C  E1E  E2_1a  E2_1b  E2_1c  E2_1d  ...  \
# 0      16.0    1.0   60.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
# 1      16.0    2.0   87.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
# 2      16.0    1.0   38.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
# 3      16.0    2.0   43.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
# 4      16.0    1.0   41.0   2.0  2.0  2.0      1    1.0    2.0    2.0  ...
# ...     ...    ...    ...   ...  ...  ...    ...    ...    ...    ...  ...
# 22067  19.0    1.0   23.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
# 22068  19.0    2.0   31.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
# 22069  19.0    2.0   79.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
# 22070  19.0    2.0   60.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
# 22071  19.0    1.0   72.0   1.0  1.0  1.0      1    2.0    2.0    2.0  ...
#
#        W129  X130  X131  X132  Y133  CLASE_PR  IMC  SEVERIDAD_DEPRESIVA  \
# 0       9.0   4.0   1.0   2.0     0       5.0  2.0                  1.0
# 1       NaN   3.0   1.0   2.0     0       1.0  9.0                  3.0
# 2       9.0   4.0   1.0   4.0     0       4.0  3.0                  3.0
# 3       8.0   2.0   1.0   2.0     1       1.0  2.0                  1.0
# 4       NaN   4.0   1.0   5.0     0       4.0  3.0                  1.0
# ...     ...   ...   ...   ...   ...       ...  ...                  ...
# 22067   NaN   1.0   1.0   2.0     0       5.0  3.0                  1.0
# 22068   NaN   4.0   1.0   2.0     0       2.0  2.0                  1.0
# 22069   NaN   4.0   1.0   1.0     0       9.0  3.0                  1.0
# 22070   NaN   4.0   1.0   2.0     0       5.0  3.0                  1.0
# 22071   NaN   4.0   1.0   1.0     0       3.0  3.0                  1.0
#
#        CUADROS_DEPRESIVOS  dep_anx
# 0                     3.0        0
# 1                     3.0        0
# 2                     2.0        0
# 3                     3.0        0
# 4                     3.0        0
# ...                   ...      ...
# 22067                 3.0        0
# 22068                 3.0        0
# 22069                 3.0        0
# 22070                 3.0        0
# 22071                 3.0        0
#
# [22072 rows x 348 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22072 entries, 0 to 22071
# Columns: 348 entries, CCAA to dep_anx
# dtypes: float64(135), int64(213)
# memory usage: 58.6 MB

# %%
df.describe()
# Out:
#                CCAA         SEXOa         EDADa          E1_1           E1C  \
# count  22072.000000  22072.000000  22072.000000  22072.000000  22072.000000
# mean       8.926332      1.529268     54.574529      1.092561      1.095279
# std        5.011998      0.499154     19.010907      0.289822      0.312446
# min        1.000000      1.000000     15.000000      1.000000      1.000000
# 25%        5.000000      1.000000     41.000000      1.000000      1.000000
# 50%        9.000000      2.000000     55.000000      1.000000      1.000000
# 75%       13.000000      2.000000     69.000000      1.000000      1.000000
# max       19.000000      2.000000    104.000000      2.000000      9.000000
#
#                 E1E         E2_1a         E2_1b         E2_1c    E2_1d  ...  \
# count  22072.000000  22072.000000  22072.000000  22072.000000  22072.0  ...
# mean       1.096095      0.940468      1.915005      1.999955      2.0  ...
# std        0.340651      0.236624      0.278880      0.006731      0.0  ...
# min        1.000000      0.000000      1.000000      1.000000      2.0  ...
# 25%        1.000000      1.000000      2.000000      2.000000      2.0  ...
# 50%        1.000000      1.000000      2.000000      2.000000      2.0  ...
# 75%        1.000000      1.000000      2.000000      2.000000      2.0  ...
# max        9.000000      1.000000      2.000000      2.000000      2.0  ...
#
#                W129          X130          X131          X132          Y133  \
# count  14254.000000  22072.000000  22072.000000  22072.000000  22072.000000
# mean       8.060334      3.158074      1.221004      2.241573      0.103117
# std        3.741996      0.860626      0.747307      1.296754      0.304119
# min        1.000000      1.000000      1.000000      1.000000      0.000000
# 25%        8.000000      3.000000      1.000000      1.000000      0.000000
# 50%        8.000000      3.000000      1.000000      2.000000      0.000000
# 75%        9.000000      4.000000      1.000000      3.000000      0.000000
# max       99.000000      9.000000      9.000000      9.000000      1.000000
#
#            CLASE_PR           IMC  SEVERIDAD_DEPRESIVA  CUADROS_DEPRESIVOS  \
# count  22072.000000  22072.000000         22072.000000        22072.000000
# mean       4.144844      3.027048             1.275689            2.954920
# std        1.838083      1.591896             0.910807            0.641339
# min        1.000000      1.000000             1.000000            1.000000
# 25%        3.000000      2.000000             1.000000            3.000000
# 50%        4.000000      3.000000             1.000000            3.000000
# 75%        5.000000      3.000000             1.000000            3.000000
# max        9.000000      9.000000             9.000000            9.000000
#
#             dep_anx
# count  22072.000000
# mean       0.131796
# std        0.338276
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 348 columns]

# %%
#numero de filas y columnas
print(f'Filas: {df.shape[0]}, Columnas : {df.shape[1]}')
# Out:
# Filas: 22072, Columnas : 348

# %%
#nombres columnas
print(df.columns)
# Out:
# Index(['CCAA', 'SEXOa', 'EDADa', 'E1_1', 'E1C', 'E1E', 'E2_1a', 'E2_1b',
#        'E2_1c', 'E2_1d',
#        ...
#        'W129', 'X130', 'X131', 'X132', 'Y133', 'CLASE_PR', 'IMC',
#        'SEVERIDAD_DEPRESIVA', 'CUADROS_DEPRESIVOS', 'dep_anx'],
#       dtype='object', length=348)

# %%
#valores unicos en cada columna
print(df.nunique())
# Out:
# CCAA                   19
# SEXOa                   2
# EDADa                  90
# E1_1                    2
# E1C                     4
#                        ..
# CLASE_PR                7
# IMC                     5
# SEVERIDAD_DEPRESIVA     6
# CUADROS_DEPRESIVOS      4
# dep_anx                 2
# Length: 348, dtype: int64

# %%
#Valores unicos por columna

numero_minimo = 10

for columna in df.columns:
    # Verifica si la columna tiene menos de 10 valores únicos
    if df[columna].nunique() < numero_minimo:
        # Imprime los valores únicos de la columna 'neighbourhood_group'
        print(f"Valores únicos de {columna}: {df[columna].unique()}")
# Out:
# Valores únicos de SEXOa: [1. 2.]
# Valores únicos de E1_1: [1. 2.]
# Valores únicos de E1C: [1. 2. 8. 9.]
# Valores únicos de E1E: [1. 2. 8. 9.]
# Valores únicos de E2_1a: [1 0]
# Valores únicos de E2_1b: [2. 1.]
# Valores únicos de E2_1c: [2. 1.]
# Valores únicos de E2_1d: [2.]
# Valores únicos de E4: [1. 3. 9. 2. 8.]
# Valores únicos de E4b: [2. 3. 1. 5. 4. 9. 8.]
# Valores únicos de ESTUDIOS: [7. 6. 9. 4. 8. 5. 3. 2.]
# Valores únicos de F6: [nan  2.  3.  1.  4.  8.  9.]
# Valores únicos de F15: [ 1. nan  2.  3.  9.  4.  5.  8.]
# Valores únicos de F16: [ 1. nan  2.  9.  8.]
# Valores únicos de F20: [nan  1.  2.  3.  4.  5.  6.  8.  9.]
# Valores únicos de G21: [2. 4. 3. 1. 5.]
# Valores únicos de G22: [2. 1. 8. 9.]
# Valores únicos de G23: [3. 1. 2. 8. 9.]
# Valores únicos de G24: [nan  1.  3.  2.  9.  8.]
# Valores únicos de G24a: [2. 4. 3. 1. 5. 8. 9.]
# Valores únicos de G25a_1: [1 0]
# Valores únicos de G25b_1: [0 1]
# Valores únicos de G25c_1: [1 0]
# Valores únicos de G25a_2: [0 1]
# Valores únicos de G25b_2: [0 1]
# Valores únicos de G25c_2: [0 1]
# Valores únicos de G25d_2: [0 1]
# Valores únicos de G25a_3: [0 1]
# Valores únicos de G25b_3: [0 1]
# Valores únicos de G25c_3: [0 1]
# Valores únicos de G25a_4: [0 1]
# Valores únicos de G25b_4: [0 1]
# Valores únicos de G25c_4: [0 1]
# Valores únicos de G25a_5: [0 1]
# Valores únicos de G25b_5: [0 1]
# Valores únicos de G25c_5: [0 1]
# Valores únicos de G25a_6: [0 1]
# Valores únicos de G25b_6: [0 1]
# Valores únicos de G25c_6: [0 1]
# Valores únicos de G25a_7: [0 1]
# Valores únicos de G25b_7: [0 1]
# Valores únicos de G25c_7: [0 1]
# Valores únicos de G25a_8: [0 1]
# Valores únicos de G25b_8: [0 1]
# Valores únicos de G25c_8: [0 1]
# Valores únicos de G25a_9: [1 0]
# Valores únicos de G25b_9: [0 1]
# Valores únicos de G25c_9: [1 0]
# Valores únicos de G25a_10: [0 1]
# Valores únicos de G25b_10: [0 1]
# Valores únicos de G25c_10: [0 1]
# Valores únicos de G25a_11: [0 1]
# Valores únicos de G25b_11: [0 1]
# Valores únicos de G25c_11: [0 1]
# Valores únicos de G25a_12: [0 1]
# Valores únicos de G25b_12: [0 1]
# Valores únicos de G25c_12: [0 1]
# Valores únicos de G25a_13: [0 1]
# Valores únicos de G25b_13: [0 1]
# Valores únicos de G25c_13: [0 1]
# Valores únicos de G25a_14: [0 1]
# Valores únicos de G25b_14: [0 1]
# Valores únicos de G25c_14: [0 1]
# Valores únicos de G25a_15: [0 1]
# Valores únicos de G25b_15: [0 1]
# Valores únicos de G25c_15: [0 1]
# Valores únicos de G25a_16: [0 1]
# Valores únicos de G25b_16: [0 1]
# Valores únicos de G25c_16: [0 1]
# Valores únicos de G25a_17: [0 1]
# Valores únicos de G25b_17: [0 1]
# Valores únicos de G25c_17: [0 1]
# Valores únicos de G25a_18: [0 1]
# Valores únicos de G25b_18: [0 1]
# Valores únicos de G25c_18: [0 1]
# Valores únicos de G25a_19: [0 1]
# Valores únicos de G25b_19: [0 1]
# Valores únicos de G25c_19: [0 1]
# Valores únicos de G25a_20: [2. 1. 9. 8.]
# Valores únicos de G25b_20: [nan  1.  2.  8.  9.]
# Valores únicos de G25c_20: [nan  1.  2.  9.]
# Valores únicos de G25a_21: [2. 1. 9. 8.]
# Valores únicos de G25b_21: [nan  1.  2.  9.  8.]
# Valores únicos de G25c_21: [nan  2.  1.  8.]
# Valores únicos de G25a_22: [0 1]
# Valores únicos de G25b_22: [0 1]
# Valores únicos de G25c_22: [0 1]
# Valores únicos de G25a_23: [0 1]
# Valores únicos de G25b_23: [0 1]
# Valores únicos de G25c_23: [0 1]
# Valores únicos de G25d_23: [0 1]
# Valores únicos de G25a_24: [0 1]
# Valores únicos de G25b_24: [0 1]
# Valores únicos de G25c_24: [0 1]
# Valores únicos de G25a_25: [0 1]
# Valores únicos de G25b_25: [0 1]
# Valores únicos de G25c_25: [0 1]
# Valores únicos de G25a_26: [0 1]
# Valores únicos de G25b_26: [0 1]
# Valores únicos de G25c_26: [0 1]
# Valores únicos de G25a_27: [0 1]
# Valores únicos de G25b_27: [0 1]
# Valores únicos de G25c_27: [0 1]
# Valores únicos de G25a_28: [0 1]
# Valores únicos de G25b_28: [0 1]
# Valores únicos de G25c_28: [0 1]
# Valores únicos de G25a_29: [1 0]
# Valores únicos de G25b_29: [0 1]
# Valores únicos de G25c_29: [1 0]
# Valores únicos de G25a_30: [0 1]
# Valores únicos de G25b_30: [0 1]
# Valores únicos de G25c_30: [0 1]
# Valores únicos de G25a_31: [0 1]
# Valores únicos de G25b_31: [0 1]
# Valores únicos de G25c_31: [0 1]
# Valores únicos de G25a_32: [0 1]
# Valores únicos de G25b_32: [0 1]
# Valores únicos de G25c_32: [0 1]
# Valores únicos de H26_1: [0 1]
# Valores únicos de H26_2: [0 1]
# Valores únicos de H26_3: [0 1]
# Valores únicos de H27: [nan  2.  4.  3.  1.  8.  9.]
# Valores únicos de J30: [0 1]
# Valores únicos de K32: [1. 2. 9. 3.]
# Valores únicos de K33: [ 1.  3.  2.  4.  8. nan  9.]
# Valores únicos de K34: [2. 1. 3. 9.]
# Valores únicos de K35: [ 1.  2.  3.  4. nan  8.]
# Valores únicos de K36: [ 1.  3.  2.  4.  8. nan  9.]
# Valores únicos de K37: [1. 3. 2. 4.]
# Valores únicos de K38: [1. 4. 3. 2.]
# Valores únicos de K38a: [1. 2. 4. 3.]
# Valores únicos de K38b: [ 1.  2. nan  3.  4.]
# Valores únicos de L39_1: [ 1.  3. nan  2.  4.]
# Valores únicos de L39_2: [ 1.  2. nan  3.  4.]
# Valores únicos de L39_3: [ 1.  3. nan  4.  2.]
# Valores únicos de L39_4: [ 1.  2. nan  4.  3.]
# Valores únicos de L39_5: [ 1.  4. nan  3.  2.]
# Valores únicos de L40: [nan  1.  2.]
# Valores únicos de L41: [nan  2.  1.  8.]
# Valores únicos de L42_1: [ 1.  3. nan  5.  4.  2.]
# Valores únicos de L42_2: [ 1. nan  3.  4.  2.  5.]
# Valores únicos de L42_3: [ 1.  3. nan  4.  2.  5.]
# Valores únicos de L42_4: [ 1. nan  4.  2.  3.  5.]
# Valores únicos de L42_5: [ 1.  3. nan  5.  4.  2.]
# Valores únicos de L42_6: [ 1.  4. nan  3.  2.  5.]
# Valores únicos de L42_7: [ 1. nan  3.  4.  2.  5.]
# Valores únicos de L43: [nan  1.  2.]
# Valores únicos de L44: [nan  2.  1.  8.]
# Valores únicos de L45: [1. 5. 4. 3. 2. 6. 8. 9.]
# Valores únicos de L46: [1. 5. 2. 4. 3. 8. 9.]
# Valores únicos de N48: [3. 2. 1. 4.]
# Valores únicos de N50: [2. 1. 3. 4. 8. 9.]
# Valores únicos de N58_1: [0 1]
# Valores únicos de N58_2: [0 1]
# Valores únicos de N58_3: [0 1]
# Valores únicos de N59: [0 1]
# Valores únicos de N60_1: [0 1]
# Valores únicos de N60_2: [0 1]
# Valores únicos de N60_3: [0 1]
# Valores únicos de N60_4: [0 1]
# Valores únicos de N60a_1: [0 1]
# Valores únicos de N60a_2: [0 1]
# Valores únicos de N60a_3: [0 1]
# Valores únicos de N60a_4: [0 1]
# Valores únicos de N61_1: [0 1]
# Valores únicos de N61_2: [0 1]
# Valores únicos de N61_4: [0 1]
# Valores únicos de N61_5: [0 1]
# Valores únicos de N62: [1. 3. 4. 2. 5.]
# Valores únicos de N63_1: [1 0]
# Valores únicos de N63_2: [1 0]
# Valores únicos de N63_3: [0 1]
# Valores únicos de N63_4: [0 1]
# Valores únicos de N63_5: [0 1]
# Valores únicos de N63_6: [0 1]
# Valores únicos de N63_7: [0 1]
# Valores únicos de N63_8: [0 1]
# Valores únicos de N63_9: [0 1]
# Valores únicos de N63_10: [0 1]
# Valores únicos de N64: [ 3.  1. nan  2.  4.  8.  9.]
# Valores únicos de N65_1: [0 1]
# Valores únicos de N65_2: [1 0]
# Valores únicos de N65_3: [0 1]
# Valores únicos de N65_4: [0 1]
# Valores únicos de N65_5: [0 1]
# Valores únicos de N65_6: [1 0]
# Valores únicos de N65_7: [1 0]
# Valores únicos de N65_8: [0 1]
# Valores únicos de O66: [0 1]
# Valores únicos de O69: [0 1]
# Valores únicos de O71: [nan  3.  1.  4.  2.  5.  8.  9.]
# Valores únicos de O74: [nan  1.  3.  2.  5.  4.  9.  8.]
# Valores únicos de O75: [0 1]
# Valores únicos de O78: [0 1]
# Valores únicos de O80_1: [0 1]
# Valores únicos de O80_2: [0 1]
# Valores únicos de O80_3: [0 1]
# Valores únicos de O83: [nan  1.  4.  2.  3.  6.  5.  8.  9.]
# Valores únicos de O84_1: [1 0]
# Valores únicos de O84_2: [0 1]
# Valores únicos de O84_3: [0 1]
# Valores únicos de O84_4: [0 1]
# Valores únicos de O84_5: [0 1]
# Valores únicos de O84_6: [0 1]
# Valores únicos de O84_7: [0 1]
# Valores únicos de O84_8: [0 1]
# Valores únicos de O84_9: [0 1]
# Valores únicos de P85: [0 1]
# Valores únicos de P86: [0 1]
# Valores únicos de P87_1a: [0 1]
# Valores únicos de P87_1b: [0 1]
# Valores únicos de P87_2a: [0 1]
# Valores únicos de P87_2b: [0 1]
# Valores únicos de P87_3a: [0 1]
# Valores únicos de P87_3b: [0 1]
# Valores únicos de P87_4a: [0 1]
# Valores únicos de P87_4b: [0 1]
# Valores únicos de P87_5a: [0 1]
# Valores únicos de P87_5b: [0 1]
# Valores únicos de P87_6a: [0 1]
# Valores únicos de P87_6b: [0 1]
# Valores únicos de P87_7a: [0 1]
# Valores únicos de P87_7b: [0 1]
# Valores únicos de P87_8a: [0 1]
# Valores únicos de P87_8b: [0 1]
# Valores únicos de P87_9a: [0 1]
# Valores únicos de P87_9b: [0 1]
# Valores únicos de P87_10a: [0 1]
# Valores únicos de P87_10b: [0 1]
# Valores únicos de P87_11a: [0 1]
# Valores únicos de P87_11b: [0 1]
# Valores únicos de P87_12a: [0 1]
# Valores únicos de P87_12b: [0 1]
# Valores únicos de P87_13a: [0 1]
# Valores únicos de P87_13b: [0 1]
# Valores únicos de P87_14a: [0 1]
# Valores únicos de P87_14b: [0 1]
# Valores únicos de P87_15a: [0 1]
# Valores únicos de P87_15b: [0 1]
# Valores únicos de P87_16a: [0 1]
# Valores únicos de P87_16b: [0 1]
# Valores únicos de P87_17a: [0 1]
# Valores únicos de P87_17b: [0 1]
# Valores únicos de P87_18a: [0 1]
# Valores únicos de P87_18b: [0 1]
# Valores únicos de P87_19a: [0 1]
# Valores únicos de P87_19b: [0 1]
# Valores únicos de P87_20a: [0 1]
# Valores únicos de P87_20b: [0 1]
# Valores únicos de P87_21a: [0 1]
# Valores únicos de P87_21b: [0 1]
# Valores únicos de P87_22a: [0 1]
# Valores únicos de P87_22b: [0 1]
# Valores únicos de P87_23a: [0 1]
# Valores únicos de P87_23b: [0 1]
# Valores únicos de Q88: [0 1]
# Valores únicos de Q89: [1 0]
# Valores únicos de Q90: [ 2.  1. nan  8.  3.  4.  5.  9.]
# Valores únicos de Q91: [1 0]
# Valores únicos de Q92: [ 2.  1.  4. nan  8.  3.]
# Valores únicos de Q93: [1 0]
# Valores únicos de Q94: [ 2.  1.  4. nan  3.  8.]
# Valores únicos de Q95: [1 0]
# Valores únicos de Q96: [ 1.  3. nan  5.  2.  4.  8.  9.]
# Valores únicos de Q98: [0 1]
# Valores únicos de Q99: [nan  4.  3.  1.  2.  8.  9.]
# Valores únicos de Q100: [0 1]
# Valores únicos de Q101: [nan  4.  1.  2.  3.  8.  9.]
# Valores únicos de Q103: [0 1]
# Valores únicos de Q104: [nan  5.  1.  2.  3.  4.  8.  9.]
# Valores únicos de R106: [0 1]
# Valores únicos de R107: [0 1]
# Valores únicos de R108_1: [0 1]
# Valores únicos de R108_2: [0 1]
# Valores únicos de R108_3: [0 1]
# Valores únicos de R108_4: [0 1]
# Valores únicos de T111: [1. 3. 4. 2. 5. 8. 9.]
# Valores únicos de T112: [2. 1. 3. 8. 4. 9.]
# Valores únicos de T114: [ 2. nan  1.  3.  8.  4.  5.]
# Valores únicos de T116: [nan  2.  1.  3.  4.  5.  8.  9.]
# Valores únicos de U120_1: [6. 1. 3. 5. 2. 4. 8. 9.]
# Valores únicos de U120_2: [1. 4. 3. 5. 2. 6. 8. 9.]
# Valores únicos de U120_3: [2. 5. 4. 3. 1. 6. 8. 9.]
# Valores únicos de U120_4: [1. 4. 3. 5. 2. 6. 9. 8.]
# Valores únicos de U120_5: [4. 2. 1. 5. 3. 6. 8. 9.]
# Valores únicos de U120_6: [1. 5. 6. 2. 4. 3. 8. 9.]
# Valores únicos de U120_7: [1. 3. 2. 4. 5. 6. 9. 8.]
# Valores únicos de U120_8: [6. 5. 4. 3. 2. 1. 9. 8.]
# Valores únicos de U120_9: [3. 5. 1. 4. 6. 2. 8. 9.]
# Valores únicos de U120_10: [1. 5. 4. 2. 6. 3. 9. 8.]
# Valores únicos de U120_11: [4. 1. 3. 2. 5. 6. 9. 8.]
# Valores únicos de U120_12: [6. 1. 5. 3. 2. 4. 9. 8.]
# Valores únicos de U120_13: [6. 5. 4. 2. 3. 1. 9. 8.]
# Valores únicos de U120_14: [6. 4. 5. 3. 2. 1. 8. 9.]
# Valores únicos de U120_15: [6. 1. 4. 5. 2. 3. 8. 9.]
# Valores únicos de U120FZ: [0 1]
# Valores únicos de V121: [3. 4. 1. 2. 9. 8.]
# Valores únicos de V124a: [1 0]
# Valores únicos de V126: [4. 1. 2. 3. 9. 8.]
# Valores únicos de V126a: [nan  1.  2.  3.]
# Valores únicos de V126b: [3. 2. 8. 1. 9.]
# Valores únicos de V126c: [nan  2.  1.]
# Valores únicos de X130: [4. 3. 2. 8. 1. 9.]
# Valores únicos de X131: [1. 8. 3. 2. 4. 5. 9.]
# Valores únicos de X132: [2. 4. 5. 8. 1. 3. 9.]
# Valores únicos de Y133: [0 1]
# Valores únicos de CLASE_PR: [5. 1. 4. 3. 9. 2. 6.]
# Valores únicos de IMC: [2. 9. 3. 4. 1.]
# Valores únicos de SEVERIDAD_DEPRESIVA: [1. 3. 4. 2. 5. 9.]
# Valores únicos de CUADROS_DEPRESIVOS: [3. 2. 1. 9.]
# Valores únicos de dep_anx: [0 1]

# %%
#Copiamos el dataframe para no ser destructivos con los datos
clean_df = df.copy()

# %% [markdown]
# ### Univariable Description

# %%
var_x = 'SEXOa'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %%
var_x = 'CCAA'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %% [markdown]
# Countplot de fumadores

# %%
var_x = 'V121'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %% [markdown]
# Tiene nacionalidad Española

# %%
var_x = 'E2_1a'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %% [markdown]
# Estado civil

# %%
var_x = 'E4b'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %% [markdown]
# Estado salud 12 meses

# %%
var_x = 'G21'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %% [markdown]
# -    1 -Muy bueno
# -    2 -Buenp
# -    3 -Regular
# -    4 - Malo
# -    5- Muy malo

# %% [markdown]
# #### Target

# %%
var_x = 'dep_anx'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %% [markdown]
# Antidepresivos consumidos

# %%
var_x = 'P87_14a'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %%
clean_df['P87_14a'].value_counts()
# Out:
# P87_14a
# 0    20833
# 1     1239
# Name: count, dtype: int64

# %% [markdown]
# Antidepresivos recetados

# %%
var_x = 'P87_14b'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %%
clean_df['P87_14b'].value_counts()
# Out:
# P87_14b
# 0    20836
# 1     1236
# Name: count, dtype: int64

# %% [markdown]
# Tranquilizantes, relajantes, pastillas para dormir consumidas

# %%
var_x = 'P87_7a'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %%
clean_df['P87_7a'].value_counts()
# Out:
# P87_7a
# 0    19077
# 1     2995
# Name: count, dtype: int64

# %% [markdown]
# Tranquilizantes, relajantes, pastillas para dormir recetadas

# %%
var_x = 'P87_7b'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %%
clean_df['P87_7b'].value_counts()
# Out:
# P87_7b
# 0    19147
# 1     2925
# Name: count, dtype: int64

# %% [markdown]
# Consumo de comida rapida
# - U120_13

# %%
var_x = 'U120_13'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %%
clean_df['U120_13'].value_counts()
# Out:
# U120_13
# 5.0    8047
# 6.0    7965
# 4.0    4643
# 3.0     742
# 2.0     360
# 1.0     283
# 9.0      18
# 8.0      14
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def plot_single_numerical_variable(dataframe, column):

    fig, axis = plt.subplots(2, 1, figsize=(8, 4), gridspec_kw={'height_ratios': [6, 1]})

    # Calcula la media, mediana y desviación estándar de los datos
    media = np.mean(dataframe[column])
    mediana = np.median(dataframe[column])
    desviacion_estandar = np.std(dataframe[column])

    # Crear una figura múltiple con histogramas y diagramas de caja
    sns.histplot(ax=axis[0], data=dataframe, kde=True, x=column).set(xlabel=None)
    axis[0].axvline(media, color='red', linestyle='dashed', linewidth=1, label=f'Media: {media:.2f}' )
    axis[0].axvline(mediana, color='orange', linestyle='dashed', linewidth=1, label=f'Mediana: {mediana:.2f}')
    axis[0].axvline(media + desviacion_estandar, color='green', linestyle='dashed', linewidth=1, label=f'Desviación Estándar: {desviacion_estandar:.2f}')
    axis[0].axvline(media - desviacion_estandar, color='green', linestyle='dashed', linewidth=1)

    sns.boxplot(ax=axis[1], data=dataframe, x=column).set(xlabel=None)
    axis[1].axvline(media, color='red', linestyle='dashed', linewidth=1, label='Media')
    axis[1].axvline(mediana, color='orange', linestyle='dashed', linewidth=1, label='Mediana')
    axis[1].axvline(media + desviacion_estandar, color='green', linestyle='dashed', linewidth=1)
    axis[1].axvline(media - desviacion_estandar, color='green', linestyle='dashed', linewidth=1)

    axis[0].legend()

    fig.suptitle(column)

    # Ajustar el layout
    plt.tight_layout()

    # Mostrar el plot
    plt.show()

# Uso del código
# Supongamos que 'data' es tu DataFrame y 'variable' es la columna que deseas graficar
# plot_single_numerical_variable(data, 'variable')

# %% [markdown]
# Viejitos :3

# %%
clean_df[clean_df['EDADa'] > 100]['EDADa']
# Out:
# 6428     103.0
# 7332     102.0
# 16018    104.0
# 17527    102.0
# 17606    101.0
# 20968    103.0
# Name: EDADa, dtype: float64

# %%
clean_df.iloc[16018]
# Out:
# CCAA                     7.0
# SEXOa                    2.0
# EDADa                  104.0
# E1_1                     1.0
# E1C                      1.0
#                        ...
# CLASE_PR                 5.0
# IMC                      2.0
# SEVERIDAD_DEPRESIVA      2.0
# CUADROS_DEPRESIVOS       3.0
# dep_anx                  0.0
# Name: 16018, Length: 348, dtype: float64

# %%
clean_df['EDADa'].describe()
# Out:
# count    22072.000000
# mean        54.574529
# std         19.010907
# min         15.000000
# 25%         41.000000
# 50%         55.000000
# 75%         69.000000
# max        104.000000
# Name: EDADa, dtype: float64

# %% [markdown]
# Edad

# %%
plot_single_numerical_variable(clean_df, 'EDADa')

# %% [markdown]
# Consumo de fruta
# - U120_1

# %%
var_x = 'U120_1'

# Obtén los valores únicos y sus recuentos
counts = clean_df[var_x].value_counts()

# Crea el gráfico de barras
plt.bar(counts.index, counts.values)

# Personaliza el gráfico
plt.xlabel(var_x)
plt.ylabel('Count')
plt.title('Barplot de {}'.format(var_x))

# Muestra el gráfico
plt.show()

# %%
clean_df['U120_1'].value_counts()
# Out:
# U120_1
# 1.0    15510
# 2.0     2568
# 3.0     1679
# 4.0     1380
# 5.0      611
# 6.0      309
# 9.0       12
# 8.0        3
# Name: count, dtype: int64

# %% [markdown]
# Estudios
