# %%
import pandas as pd
import json
from unidecode import unidecode


# Lee el archivo Excel
archivo_excel = '../data/raw/disreg_enceursalud20_a.xlsx'
df = pd.read_excel(archivo_excel, sheet_name='Diseño')
df
# Out:
#                         Variable Diccionario de la variable  Longitud Tipo  \
# 0                           CCAA                      TCCAA       2.0    A
# 1                     IDENTHOGAR                        NaN       8.0    A
# 2                          A7_2a                        NaN       2.0    A
# 3                          SEXOa                      TSEXO       1.0    A
# 4                          EDADa                     N_3DIG       3.0    N
# ..                           ...                        ...       ...  ...
# 425          SEVERIDAD_DEPRESIVA                    TSEVERI       1.0    A
# 426           CUADROS_DEPRESIVOS                    TPREVAL       1.0    A
# 427                       TOTAL                         NaN       NaN  NaN
# 428                          NaN                        NaN       NaN  NaN
# 429  (b) Admite blanco por flujo                        NaN       NaN  NaN
#
#     FormatoR  Decimales  Posición  Orden Diccionario ubicado en la hoja…  \
# 0         A2        NaN       1.0    1.0                         Tablas1
# 1         A8        NaN       NaN    NaN                             NaN
# 2         A2        NaN       NaN    NaN                             NaN
# 3         A1        NaN       NaN    NaN                         Tablas1
# 4         I3        NaN       NaN    NaN                         Tablas4
# ..       ...        ...       ...    ...                             ...
# 425       A1        NaN       NaN    NaN                         Tablas1
# 426       A1        NaN       NaN    NaN                         Tablas1
# 427      NaN        NaN       NaN    NaN                             NaN
# 428      NaN        NaN       NaN    NaN                             NaN
# 429      NaN        NaN       NaN    NaN                             NaN
#
#                                            Descripción Observaciones  \
# 0                     Comunidad Autónoma de residencia           NaN
# 1    Número de identificación del hogar: sección + ...           NaN
# 2              Número de orden del adulto seleccionado           NaN
# 3    Identificación del adulto seleccionado: Sexo\n...           NaN
# 4    Identificación del adulto seleccionado: Edad. ...           NaN
# ..                                                 ...           ...
# 425  Variable derivada: Severidad de la sintomatolo...           NaN
# 426  Variable derivada: Prevalencia de cuadros depr...           NaN
# 427                                                NaN           NaN
# 428                                                NaN           NaN
# 429                                                NaN           NaN
#
#     Unnamed: 11               Unnamed: 12
# 0           NaN  DATOS DE IDENTIFICACIÓN
# 1           NaN                       NaN
# 2           NaN                       NaN
# 3           NaN                       NaN
# 4           NaN                       NaN
# ..          ...                       ...
# 425         NaN                       NaN
# 426         NaN                       NaN
# 427         NaN                       NaN
# 428         NaN                       NaN
# 429         NaN                       NaN
#
# [430 rows x 13 columns]

# %%
# Maneja los valores nulos en la columna A
df['Descripción'] = df['Descripción'].fillna('').astype(str)

df['Descripción'] = df['Descripción'].apply(unidecode)
# Convierte el DataFrame a un diccionario
data_dict = df.set_index('Variable').to_dict()['Descripción']


data_dict = {key: value.replace('\n', ' ') for key, value in data_dict.items()}
# Convierte el diccionario a formato JSON
json_data = json.dumps(data_dict, indent=2, ensure_ascii=False)


# Guarda el JSON en un archivo
with open('Diseño.json', 'w', encoding='utf-8') as file:
    file.write(json_data)

print("Archivo JSON generado con éxito.")
# Out:
# Archivo JSON generado con éxito.
