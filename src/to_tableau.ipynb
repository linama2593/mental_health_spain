# %%
import pandas as pd

# %%
df = pd.read_csv('../data/interim/df_final.csv')

# %%
df_t = df[["CCAA", "SEXOa", "EDADa", "E4b", "ESTUDIOS", "IMC", "dep_anx"]]

# %%
df_t.to_csv("../assets/web/df_tableau.csv")
